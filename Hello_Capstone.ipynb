# %% [markdown]
# # Capstone Project Week 1 Assignment
# <div class="alert alert-block alert-info">
# <span style="font-family:Comic Sans MS">This notebook will be mainly used for Capstone Project
# </span></div>

# %%
import pandas as pd
import numpy as np

# %%
statement = "Hello Capstone Project Course!"
statement
# Out:
# 'Hello Capstone Project Course!'
